# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Trabajo Semanal 12
#
# ### Jorge Andres Niño

# %% [markdown]
# ## Consigna

# %% [markdown]
# Resolver los puntos mostrados a continuación:

# %% [markdown]
# ![*Figura 8*](Ejercicio.png)

# %% [markdown]
# ### Resolución

# %% [markdown]
# A continuación se muestra la solución a ambos ejercicios:

# %%
from IPython.display import IFrame, display
IFrame("./TS12_Niño.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TS12_Niño.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Simulaciones.

# %% [markdown]
# A continuación vamos a simular en python las funciones transferencia de los dos ejercicios realizados.

# %%
# PyTC2: La librería para TC2
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot, analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti, tf2sos_analog, pretty_print_SOS

from scipy import signal as Funcion
import numpy as np
import matplotlib.pyplot as plt
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
#%% Funcion trasnferencia:
Q = 1
w0 = 1
num1= np.array([3*w0**3,0,7*w0,0])
den1 = np.array([w0**4,0, 7*w0**2, 0, 10])
H1 = Funcion.TransferFunction( num1, den1 )
fig_sz_x = 20
fig_sz_y = 10
fig_dpi = 80 # dpi
fig_font_size = 13

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

analyze_sys(H1, sys_name='Q = {:3.3f}'.format(Q))

# %%
#%% Funcion trasnferencia:
Q = 1
w0 = 1
num1= np.array([w0**3,0,w0,0])
den1 = np.array([w0**4,0, 7*w0**2, 0, 10])
H1 = Funcion.TransferFunction( num1, den1 )
fig_sz_x = 20
fig_sz_y = 10
fig_dpi = 80 # dpi
fig_font_size = 13

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

analyze_sys(H1, sys_name='Q = {:3.3f}'.format(Q))

# %% [markdown]
# ![*Figura 2*](Simu_impedancias.bmp)

# %% [markdown]
# Podemos observar que la respuesta de $Y_{21}$ e $Y_{11}$ en la simulación con python (en forma de cociente de polinomios) coincide con las admitancias obtenidas en simulación circuital del circuitos sintetizado, con lo cual podemos concluir que se trata de una sintesis que cumple las condiciones

# %% [markdown]
# A continuación simulamos el circuito 2:

# %%
#%% Funcion trasnferencia:
Q = 1
w0 = 1
num1= np.array([w0,1])
den1 = np.array([w0**2,6*w0, 8])
H1 = Funcion.TransferFunction( num1, den1 )
fig_sz_x = 20
fig_sz_y = 10
fig_dpi = 80 # dpi
fig_font_size = 13

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

analyze_sys(H1, sys_name='Q = {:3.3f}'.format(Q))

# %% [markdown]
# En cuanto a la simulación del circuito:

# %% [markdown]
# ![*Figura 3*](simu_transf_2.bmp)

# %% [markdown]
# Obtenemos tanto el mismo tipo de respuesta en magnitud como en fase pero mas atenuado en el caso de la simulación circuital

# %% [markdown]
# # Conclusiones:

# %% [markdown]
# * Se pudo comprobar la obtención de un cuadripolo que cumpla condiciones de admitancias/impedancias/transferencias pedidas, mediante los metodos  sintesis estudiados, así como su comprobación mediante los metodos analiticos. El cumplimiento de las condiciones de cortocircuito o circuito abierto deben ser prioridad para determinar desde donde encarar la sintesis, asi como para realizar la verificación.
# * Mediante LTSPICE, imponiendo condiciones de cuadripolos es posible medir admitancias e impedancias caracteristicas del cuadripolo y compararlas con la simulaciones numericas en python.
