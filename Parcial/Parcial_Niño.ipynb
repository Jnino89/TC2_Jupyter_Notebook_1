# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # 1° Parcial
# ## 10-07-2022
# ### Jorge Andres Niño

# %% [markdown]
# ## Consigna

# %% [markdown]
# Resolver los puntos mostrados en el siguiente documento:

# %%
from IPython.display import IFrame, display
IFrame("./1erParcial.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./1erParcial.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Punto 1

# %% [markdown]
# A continuación se presenta la solución obtenida al punto número 1:

# %%
from IPython.display import IFrame, display
IFrame("./Punto1.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./Punto1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Respuesta en frecuencia, fase y diagrama de polos y ceros.

# %% [markdown]
# A continuación vamos a simular en python la función transferencia obtenida, para los parametros pedidos, y luego verificaremos con LTSPICE, lo obtenido en la simulación numerica

# %%
# PyTC2: La librería para TC2
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot, analyze_sys, pretty_print_bicuad_omegayq, pretty_print_lti, tf2sos_analog, pretty_print_SOS

from scipy import signal as Funcion
import numpy as np
import matplotlib.pyplot as plt
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
#%% Funcion trasnferencia prototipo:
w0 = 1
#num1= np.array([0,0,0,1])
#den1 = np.array([w0**3,2.8399*w0**2, 4.032515*w0, 2.86298])
num1= np.array([w0**3,0,0,0])
den1 = np.array([w0**3,1.408*w0**2, 0.9916*w0, 0.3491])
H1 = Funcion.TransferFunction( num1, den1 )
pretty_print_lti(num1, den1)
fig_sz_x = 30
fig_sz_y = 20
fig_dpi = 80 # dpi
fig_font_size = 13

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

# particiono en SOS's para la implementación
sos_hp = tf2sos_analog(num1, den1)
pretty_print_SOS(sos_hp)
# Graficamos el diagrama de polos y ceros
# Graficamos la respuesta en frecuencia para el modulo y la fase.
analyze_sys(sos_hp, 'Ejercicio_integrador')
# Out:
# $\displaystyle \frac{s^3 }{s^3 + s^2 \,\, 1.408 + s \,\, 0.9916 + 0.3491 }$
# $\displaystyle   \frac{s \,\, 1.153 }{s + 0.7039 } . \frac{s^2 \,\, 0.8671 }{s^2 + s \,\, 0.7041 + 0.496 }$

# %% [markdown]
# Ahora implementamos ambos tipos de circuito, mediante estructura pasiva y luego activado con un GIC como en la resolución

# %% [markdown]
# ![*Figura 1*](CIR_PTO1_PAS.png)

# %% [markdown]
# ![*Figura 2*](SIM_PTO1_PAS.png)

# %% [markdown]
# Como vemos a ${f_o}\over{3}$ tenemos la atenuación calculada de $-19.5 db$ mayor a la pedida ($16db$) y en la frecuencia de corte a $1Hz$ tenemos unos $0.525 db$ cumpliendo con la plantilla pedida. A continuación observamos la simulación con activación de inductancia:

# %% [markdown]
# ![*Figura 3*](SIM_PTO1_ACT.png)

# %% [markdown]
# ![*Figura 4*](CIR_PTO1_ACT.png)

# %% [markdown]
# ## Punto 2

# %% [markdown]
# A contiuación se presenta la resolución del punto 2:

# %%
from IPython.display import IFrame, display
IFrame("./Punto2.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./Punto2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#%% Funcion transferencia pasa-altos:
w0 = 1
num1= np.array([w0**2,-np.sqrt(2)*w0,1])
den1 = np.array([w0**2, np.sqrt(2)*w0, 1])
H1 = Funcion.TransferFunction( num1, den1 )
pretty_print_lti(num1, den1)
fig_sz_x = 25
fig_sz_y = 15
fig_dpi = 80 # dpi
fig_font_size = 13

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

# particiono en SOS's para la implementación
sos_hp = tf2sos_analog(num1, den1)
pretty_print_SOS(sos_hp)
# Graficamos el diagrama de polos y ceros
# Graficamos la respuesta en frecuencia para el modulo y la fase.
analyze_sys(sos_hp, 'Ejercicio_integrador')
# Out:
# $\displaystyle \frac{s^2 + s \,\, -1.414 +   1 }{s^2 + s \,\, 1.414 +   1 }$
# $\displaystyle   \frac{s^2 + s \,\, -1.414 +   1 }{s^2 + s \,\, 1.414 +   1 }$

# %% [markdown]
# Podemos observar que la respuesta de la fase obtenida mediante esta función transferencia obedece a la calculada.

# %% [markdown]
# ![*Figura 5*](CIR_PTO2_LAT.png)

# %% [markdown]
# ![*Figura 6*](SIM_PTO2_LAT.png)

# %% [markdown]
# A continuación simulamos el circuito activo en LTSPICE, de acuerdo con la resolución vista:

# %% [markdown]
# ![*Figura 7*](CIR_PTO2_ACT.png)

# %% [markdown]
# ![*Figura 8*](SIM_PTO2_ACT.png)
