# %% [markdown]
# <img src="img/TPL1_Logo_UTN.svg" align="right" width="150" />
#
# ##
#
# ## Teoría de Circuitos II
#
# #### Profesor: Mariano Llamedo Soria
# #### Jefe de TPs: César Fuoco
# #### Ayudante de TPs: Israel Pavelek
#
# ####

# %% [markdown]
# ***
#
# ####
#
# ## <span style="text-decoration: underline;">Trabajo Práctico de Laboratorio N° 1: Teoría Moderna y Filtrado Activo</span>
#
# ####
#
# ## Autor
# #### *Niño, Jorge Andrés* <jnino@frba.utn.edu.ar>
#
# ## Integrantes Grupo 1
# #### *Niño, Jorge Andrés*
# #### *Celada, Matías Iván*
# #### *Gerez, Victor Rodolfo*
# #### *Moharos, David Santiago*
# ####
#
# ***

# %% [markdown]
# ## <span style="text-decoration: underline;">Objetivos</span>
#
# #### - Consolidar los conceptos de teoría moderna mediante la implementación circuital.
# #### - Simular e implementar el filtro con componentes activos de precisión.
# #### - Medir las partes de la función transferencia para frecuencias menores a 100 kHz.
#
# ####
#
# ## <span style="text-decoration: underline;">Descripción</span>
#
# #### Diseñar y ensayar un filtro que responda a la siguiente plantilla.
#
# ####
#
# <img src="img/TPL1_Plantilla_Filtro_HP_Datos.png" style="margin-left:auto; margin-right:auto"/>
#
# ####
#
# ***

# %% [markdown]
# ## <span style="text-decoration: underline;">Introducción:</span>
#
# #### El trabajo práctico implica la implementación de una función transferencia con el circuito integrado [UAF42](https://www.ti.com/lit/ds/symlink/uaf42.pdf?ts=1653513515595&ref_url=https%253A%252F%252Fwww.ti.com%252Fproduct%252FUAF42%253Futm_source%253Dsupplyframe%2526utm_medium%253DSEP%2526utm_campaign%253Dnot_alldatasheet%2526DCM%253Dyes%2526dclid%253DCOTE4LXH-_cCFaCFlQIdQoELbA) que posee capacitores integrados de muy baja tolerancia. Esto permite obtener respuestas en frecuencia del filtro mucho mas precisas que con un sistema discreto.
#
# ####
#
# ***
#
# ### <span style="text-decoration: underline;">Sintesís:</span>
#
# #### - Obtener el orden del filtro y el ε.
# #### - Obtener la función transferencia en el dominio de Laplace. Identificar polos y ceros.
# #### - Sintetizar los valores de los componentes externos del circuito UAF42.
#
# ####
#
# ***

# %% [markdown]
# ### Desarrollo de la síntesis ###

# %%
from IPython.display import IFrame, display
IFrame("./TPL1_res.pdf", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="./TPL1_res.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### <span style="text-decoration: underline;">Datos de plantilla filtro pasa altos objetivo</span>
#
# ####
#
# <img src="img/TPL1_Plantilla_Filtro_HP_Grafica.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# \begin{equation}
# α_{mín}= 20 dB
# \end{equation}
#
# \begin{equation}
# α_{máx}= 1 dB
# \end{equation}
#
# \begin{equation}
# f_s= 1200 Hz
# \end{equation}
#
# \begin{equation}
# f_p= 4600 Hz
# \end{equation}

# %% [markdown]
# #### Normalización de plantilla pasa altos objetivo:
#
# \begin{equation}
# ω_{s_n}= \frac{ω_s}{Ω_ω}= \frac{ω_s}{ω_p}= \frac{2*π*1200 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 0,2609
# \end{equation}
#
# \begin{equation}
# ω_{p_n}= \frac{ω_p}{Ω_ω}= \frac{ω_p}{ω_p}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 1
# \end{equation}
#
# ####
#
# ***

# %% [markdown]
# ### <span style="text-decoration: underline;">Datos de plantilla filtro pasa bajos prototipo</span>
#
# ####
#
# <img src="img/TPL1_Plantilla_Filtro_LP.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# \begin{equation}
# Ω=\frac{1}{ω}
# \end{equation}
#
# \begin{equation}
# Ω_{s_n}= \frac{1}{ω_{s_n}}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*1200 [\frac{rad}{s}]}= 3,8333
# \end{equation}
#
# \begin{equation}
# Ω_{p_n}= \frac{1}{ω_{p_n}}= \frac{2*π*4600 [\frac{rad}{s}]}{2*π*4600 [\frac{rad}{s}]}= 1
# \end{equation}
#
# ####
#
# ***

# %% [markdown]
# ### <span style="text-decoration: underline;">Cálculo de ε y n</span>
#
# ####
#
# \begin{equation}
# |T(jΩ)|^2= T(jΩ)*T(-jΩ)= {T(s)*T(-s)}|_{s= jΩ}= \frac{1}{1+ε^2*C_n^2(Ω)}
# \end{equation}
#
# \begin{equation}
# |α|^2= 1+ε^2*C_n^2(Ω)
# \end{equation}
#
# \begin{equation}
# |α|_{dB} \triangleq α_{dB}
# \end{equation}
#
# \begin{equation}
# α_{dB}= 10*log[1+ε^2*C_n^2(Ω)]
# \end{equation}
#
# \begin{equation}
# ε^2= \frac{10^{\frac{α_{máx}}{10}}-1}{C_n^2(Ω)}
# \end{equation}
#
# ####
#
# \begin{equation}
# (α_{máx}; Ω_{p_n}): ε^2= \frac{10^{\frac{α_{máx}}{10}}-1}{C_n^2(Ω_{p_n})}= \frac{10^{\frac{20}{10}}-1}{1}
# \end{equation}
#
# \begin{equation}
# \boxed{ε^2= 0,2589}
# \end{equation}
#
# \begin{equation}
# \boxed{ε= 0,5088}
# \end{equation}
#
# ####
#
# \begin{equation}
# (α_{mín}, Ω_{s_n}): α_{mín} = 10*log[1 + ε^2*C_n^2(Ω_{s_n})]
# \end{equation}
#
# \begin{equation}
# n= 1: ¿α(Ω_{s_n}) = 6.8167 dB \geq α_{mín}= 20 dB? \rightarrow No...
# \end{equation}
#
# \begin{equation}
# n= 2: ¿α(Ω_{s_n}) = 23.2155 dB \geq α_{mín}= 20 dB? \rightarrow ¡Sí!
# \end{equation}
#
# \begin{equation}
# \boxed{n= 2}
# \end{equation}
#
# #### Cálculo del polinomio de Chebyshev (a partir de ahora se omite el subíndice n para los valores de frecuencia normalizados):
# <br>
#
# \begin{equation}
# C_n^2= cosh^2(n*cosh^{-1}(Ω_{s}))
# \end{equation}
#
# \begin{equation}
# C_0(Ω)= 1
# \end{equation}
#
# \begin{equation}
# C_1(Ω)= Ω
# \end{equation}
#
# \begin{equation}
# C_n(Ω)= 2*Ω*C_{n-1}(Ω) - C_{n-2}(Ω)
# \end{equation}
#
# \begin{equation}
# C_2(Ω)= 2*Ω*Ω - 1= 2*Ω^2-1
# \end{equation}
#
# #### Cálculo de la función transferencia:
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{S}{j}}= \frac{1}{1+ε^2*C_n^2(Ω)}= \frac{1}{1+ε^2*C_2^2(Ω)}= \frac{1}{1+ε^2*(2*Ω^2-1)^2}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{S}{j}}= \frac{1}{1+ε^2*(2*Ω^2-1)^2}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{S}{j}}= \frac{1}{1+ε^2*(2*Ω^2-1)*(2*Ω^2-1)}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{S}{j}}= \frac{1}{1+ε^2*(4*Ω^4-2*Ω^2-2*Ω^2+1)}
# \end{equation}
#
# \begin{equation}
# |T(jΩ)|^2_{Ω=\frac{S}{j}}= \frac{1}{1+ε^2*(4*Ω^4-4*Ω^2+1)}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{1}{1+ε^2*[4*(\frac{S}{j})^4-4*(\frac{S}{j})^2+1]}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{1}{1+ε^2*[4*S^4+4*S^2+1]}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{1}{1+4*ε^2*^S4+4*ε^2*S^2+ε^2}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{1}{4*ε^2*S^4+4*ε^2*S^2+ε^2+1}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{\frac{1}{4*ε^2}}{\frac{4*ε^2*S^4+4*ε^2*S^2+ε^2+1}{4*ε^2}}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{\frac{1}{4*ε^2}}{S^4+S^2+\frac{ε^2+1}{4*ε^2}}
# \end{equation}
#
# #### siendo:
#
# \begin{equation}
# a= \frac{1}{4*ε^2}
# \end{equation}
#
# \begin{equation}
# b= \frac{ε^2+1}{4*ε^2}= \frac{ε^2}{4*ε^2} + \frac{1}{4*ε^2}= \frac{1}{4} + \frac{1}{4*ε^2}= \frac{1}{4} + a
# \end{equation}
#
# \begin{equation}
# \Rightarrow \, T(S)*T(-S)= \frac{a}{S^4+S^2+b}
# \end{equation}
#
# #### Considerando una SOS en su forma genérica:
#
# \begin{equation}
# T(S)*T(-S)= \frac{α}{S^2 + β*S + γ}*\frac{α}{S^2 - β*S + γ}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{α^2}{S^4 -β*S^3 +γ*S^2 +β*S^3 -β^2*S^2 +β*γ*S +γ*S^2 -β*γ*S +γ^2}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{α^2}{S^4 +(-β+β)*S^3 +(2*γ-β^2)*S^2 +(β*γ-β*γ)*S +γ^2}
# \end{equation}
#
# \begin{equation}
# T(S)*T(-S)= \frac{α^2}{S^4 +(2*γ-β^2)*S^2 +γ^2}
# \end{equation}
#
# #### Resolución del sistema de ecuaciones:
#
# \begin{equation}
# α^2= a= \frac{1}{4*ε^2}
# \end{equation}
#
# \begin{equation}
# α= \sqrt{\frac{1}{4*ε^2}}= \frac{1}{2*ε}= \frac{1}{2*0,5088}= 0.9827
# \end{equation}
#
# \begin{equation}
# 2*γ-β^2= 1
# \end{equation}
#
# \begin{equation}
# β= \sqrt{2*γ-1}
# \end{equation}
#
# \begin{equation}
# γ^2= b
# \end{equation}
#
# \begin{equation}
# γ^2= \frac{1}{4} + a
# \end{equation}
#
# \begin{equation}
# γ= \sqrt{\frac{1}{4} + a}= \sqrt{\frac{1}{4} + α^2}= \sqrt{\frac{1}{4} + 0.9827^2}= 1,1026
# \end{equation}
#
# \begin{equation}
# β= \sqrt{2*γ-1}= \sqrt{2*1,1026-1}= 1,0978
# \end{equation}
#
# #### Transferencia pasabajos prototipo (normalizada):
# <br>
#
# \begin{equation}
# \boxed{T_{LP}(S)=\frac{\frac{1}{2*ε}}{S^2 + \sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*S + \frac{\sqrt{ε^2+1}}{2*ε}}= \frac{0.9827}{S^2 + 1,0978*S + 1,1026}}
# \end{equation}
#
# #### Transformación a pasa altos aplicando núcleo de transformación:
#
# \begin{equation}
# K(s)=S= \frac{1}{s}
# \end{equation}
#
#
#
# \begin{equation}
# T(s)= \frac {\frac{1}{2*ε}}{(\frac{1}{s})^2 + \sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*(\frac{1}{s}) + \frac{\sqrt{ε^2+1}}{2*ε}}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{\frac{1}{2*ε}}{\frac{1}{s^2} + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{s} + \frac{\sqrt{ε^2+1}}{2*ε}}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{\frac{1}{2*ε}}{\frac{1 +\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*s +\frac{\sqrt{ε^2+1}}{2*ε}*s^2}{s^2}}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{\frac{1}{2*ε}*s^2}{1 +\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*s +\frac{\sqrt{ε^2+1}}{2*ε}*s^2}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac{\frac{\frac{1}{2*ε}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s^2}{\frac{1 +\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}*s +\frac{\sqrt{ε^2+1}}{2*ε}*s^2}{\frac{\sqrt{ε^2+1}}{2*ε}}}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac {\frac{\frac{1}{2*ε}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s^2} {\frac{1}{\frac{\sqrt{ε^2+1}}{2*ε}} +\frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s +\frac{\frac{\sqrt{ε^2+1}}{2*ε}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s^2}
# \end{equation}
#
# \begin{equation}
# T(s)= \frac {\frac{1}{\sqrt{ε^2+1}}*s^2} {\frac{2*ε}{\sqrt{ε^2+1}} +\frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s +s^2}
# \end{equation}
#
# #### Transferencia pasa altos objetivo (normalizada):
# <br>
#
# \begin{equation}
# \boxed{T_{HP}(s)=\frac{\frac 1{\sqrt{ε^2+1}}*s^2}{s^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s + \frac{2*ε}{\sqrt{ε^2+1}}}= \frac {0,8913*s^2} {s^2 +0,9957*s +0,9069}}
# \end{equation}
#
# #### Desnormalización con $\,s_N=\frac s{\Omega_\omega}\,\,$ siendo $\,\Omega_\omega= 2 \pi \, 4600 Hz\,\,$
#
# #### Transferencia pasa altos objetivo (desnormalizada):
# <br>
#
# \begin{equation}
# T_{HP}(s)= \frac{\frac {1}{\sqrt{ε^2+1}}*(\frac s{Ω_ω})^2}{(\frac s{Ω_ω})^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*\frac s{Ω_ω} + \frac{2*ε}{\sqrt{ε^2+1}}}
# \end{equation}
#
# \begin{equation}
# \boxed{T_{HP}(s)= \frac{\frac {1}{\sqrt{ε^2+1}} * s^2} { s^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*Ω_ω*s + \frac{2*ε}{\sqrt{ε^2+1}}*{Ω_ω}^2} = \frac{0,8913*s^2} {s^2 +2,8777*10^{4}*s +7,5764*10^{8}}}
# \end{equation}
#
# #### Polos y Ceros (normalizada):
#
# \begin{equation}
# z_{1,2}= 0
# \end{equation}
#
# \begin{equation}
# p_1= -0.4978 + j0.8118
# \end{equation}
#
# \begin{equation}
# p_2= -0.4978 - j0.8118
# \end{equation}
#
# #### <span style="text-decoration: underline;">Cálculo de los componentes externos del UAF42</span>
#
# #####
#
# ##### Considerando que:
#
# ### $T_{HP}(s)=\frac{\frac 1{\sqrt{ε^2+1}}*s^2}{s^2 + \frac{\sqrt{\frac{\sqrt{ε^2+1}}{ε}-1}}{\frac{\sqrt{ε^2+1}}{2*ε}}*s + \frac{2*ε}{\sqrt{ε^2+1}}}= \frac{k * s^2} {s^2 + \frac{ω_0}{Q}*s + ω_0^2}= \frac {0,8913*s^2} {s^2 +0,9957*s +0,9069}$
#
# ##### obtenemos los valores de $ω_0$ y Q:
#
# #####
#
# \begin{equation}
# ω_0^2= 0,9069
# \end{equation}
#
# \begin{equation}
# ω_0= 0,9523
# \end{equation}
#
# \begin{equation}
# \frac{ω_0}{Q}= 0,9957
# \end{equation}
#
# \begin{equation}
# Q= \frac{ω_0}{0,9957}= \frac{0,9523}{0,9957}= 0,9564
# \end{equation}
#
# #####
#
# ##### Utilizando las ecuaciones de diseño de la hoja de datos del UAF42:
#
# #####
#
# \begin{equation}
# ω_0^2= \frac{R_2}{R_1*R_{F1}*R_{F2}*C_1*C_2}
# \end{equation}
#
# #####
#
# \begin{equation}
# Q= \left( 1 + \frac{R_4}{R_Q} \right) * \frac{1}{\left(\frac{1}{R_1} + \frac{1}{R_2} + \frac{1}{R_G} \right)} * \sqrt{\frac{R_{F1}*C_1}{R_1*R_2*R_{F2}*C_2}}
# \end{equation}
#
# #####
#
# \begin{equation}
# A_{HP}= \frac{R_2}{R_G}
# \end{equation}
#
# #####
#
# ##### Tomando como norma de impedancia $Ω_z= R= 50KΩ$ y recordando que la norma de pulsación es $Ω_ω= ω_p= 2*\pi*4600 Hz$, obtenemos los componentes normalizados:
#
# #####
#
# \begin{equation}
# R_{1n}= \frac{R_1}{Ω_z}= \frac{R_1}{R}= 1
# \end{equation}
#
# \begin{equation}
# R_{2n}= \frac{R_2}{Ω_z}= \frac{R_2}{R}= 1
# \end{equation}
#
# \begin{equation}
# R_{4n}= \frac{R_4}{Ω_z}= \frac{R_4}{R}= 1
# \end{equation}
#
# \begin{equation}
# R_{F1n}= \frac{R_{F1}}{Ω_z}= \frac{R_{F1}}{R}= 2*10^{-5}\left[\frac{1}{Ω}\right]*R_{F1}
# \end{equation}
#
# \begin{equation}
# R_{F2n}= \frac{R_{F2}}{Ω_z}= \frac{R_{F2}}{R}= 2*10^{-5}\left[\frac{1}{Ω}\right]*R_{F2}
# \end{equation}
#
# \begin{equation}
# R_{Gn}= \frac{R_G}{Ω_z}= \frac{R_G}{R}= 2*10^{-5}\left[\frac{1}{Ω}\right]*R_G
# \end{equation}
#
# \begin{equation}
# R_{Qn}= \frac{R_Q}{Ω_z}= \frac{R_Q}{R}= 2*10^{-5}\left[\frac{1}{Ω}\right]*R_Q
# \end{equation}
#
# \begin{equation}
# C_{1n}= C_1*Ω_ω*Ω_z= C_1*ω_p*R= 1000pF * 2*π*4600\frac{rad}{s} * 50KΩ= 1,4451
# \end{equation}
#
# \begin{equation}
# C_{2n}= C_2*Ω_ω*Ω_z= C_2*ω_p*R= 1000pF * 2*π*4600\frac{rad}{s} * 50KΩ= 1,4451
# \end{equation}
#
# #####
#
# ##### Obtenemos los valores de $R_{F1n}$ y $R_{F2n}$ reemplazando los valores normalizados de los componentes en la ecuación de $ω_0^2$:
#
# #####
#
# \begin{equation}
# ω_0^2= \frac{R_{2n}}{R_{1n}*R_{F1n}*R_{F2n}*C_{1n}*C_{2n}}
# \end{equation}
#
# \begin{equation}
# R_{F1n}*R_{F2n}= \frac{R_{2n}}{R_{1n}*ω_0^2*C_{1n}*C_{2n}}
# \end{equation}
#
# \begin{equation}
# R_{F1n}*R_{F2n}= \frac{1}{1*0,9069*1,4451*1,4451}
# \end{equation}
#
# #####
#
# ##### Considerando $R_{F1n}= R_{F2n}$:
#
# #####
#
# \begin{equation}
# R_{F1n}= R_{F2n}= \sqrt{\frac{1}{0,9069*1,4451*1,4451}}= 0,7266
# \end{equation}
#
# #####
#
# ##### Obtenemos el valor de $R_{Gn}$ considerando ${A_{HP}}\Bigr|_{ω \rightarrow \infty}  \rightarrow 0,8913$ y reemplazando los valores normalizados de los componentes en la ecuación de ${A_{HP}}$:
#
# #####
#
# \begin{equation}
# A_{HP}= \frac{R_{2n}}{R_{Gn}}
# \end{equation}
#
# \begin{equation}
# R_{Gn}= \frac{R_{2n}}{A_{HP}}
# \end{equation}
#
# \begin{equation}
# R_{Gn}= \frac{1}{0,8913}= 1,1219
# \end{equation}
#
# #####
#
# ##### Obtenemos el valor de $R_{Qn}$ reemplazando los valores normalizados de los componentes en la ecuación de $Q$:
#
# #####
#
# \begin{equation}
# Q= \left( 1 + \frac{R_{4n}}{R_{Qn}} \right) * \frac{1}{\left(\frac{1}{R_{1n}} + \frac{1}{R_{2n}} + \frac{1}{R_{Gn}} \right)} * \sqrt{\frac{R_{F1n}*C_{1n}}{R_{1n}*R_{2n}*R_{F2n}*C_{2n}}}
# \end{equation}
#
# \begin{equation}
# \frac{Q}{\frac{1}{\left(\frac{1}{R_{1n}} + \frac{1}{R_{2n}} + \frac{1}{R_{Gn}} \right)} * \sqrt{\frac{R_{F1n}*C_{1n}}{R_{1n}*R_{2n}*R_{F2n}*C_{2n}}}}= 1 + \frac{R_{4n}}{R_{Qn}}
# \end{equation}
#
# \begin{equation}
# \frac{Q}{\frac{1}{\left(\frac{1}{R_{1n}} + \frac{1}{R_{2n}} + \frac{1}{R_{Gn}} \right)} * \sqrt{\frac{R_{F1n}*C_{1n}}{R_{1n}*R_{2n}*R_{F2n}*C_{2n}}}}-1= \frac{R_{4n}}{R_{Qn}}
# \end{equation}
#
# \begin{equation}
# R_{Qn}= \frac{R_{4n}}{\frac{Q}{\frac{1}{\left(\frac{1}{R_{1n}} + \frac{1}{R_{2n}} + \frac{1}{R_{Gn}} \right)} * \sqrt{\frac{R_{F1n}*C_{1n}}{R_{1n}*R_{2n}*R_{F2n}*C_{2n}}}}-1}
# \end{equation}
#
# \begin{equation}
# R_{Qn}= \frac{1}{\frac{0,9564}{\frac{1}{\left(\frac{1}{1} + \frac{1}{1} + \frac{1}{1,1219} \right)} * \sqrt{\frac{0,7266*1,4451}{1*1*0,7266*1,4451}}}-1}= \frac{1} { 0,9564*\left(2 + \frac{1}{1,1219} \right)-1 }
# \end{equation}
#
# \begin{equation}
# R_{Qn}= 0,5665
# \end{equation}
#
# #####
#
# ##### <span style="text-decoration: underline;">Valores de componentes desnormalizados:</span>
#
# #####
#
# \begin{equation}
# \boxed{C_1= 1000pF}
# \end{equation}
#
# \begin{equation}
# \boxed{C_2= 1000pF}
# \end{equation}
#
# \begin{equation}
# \boxed{R_1= 50KΩ}
# \end{equation}
#
# \begin{equation}
# \boxed{R_2= 50KΩ}
# \end{equation}
#
# \begin{equation}
# \boxed{R_4= 50KΩ}
# \end{equation}
#
# \begin{equation}
# R_{F1}= R_{F1n}*Ω_z= 0,7266*50KΩ= 36,3300KΩ \rightarrow \boxed{R_{F1}= 33KΩ + 3.3 KΩ}
# \end{equation}
#
# \begin{equation}
# R_{F2}= R_{F2n}*Ω_z= 0,7266*50KΩ= 36,3300KΩ \rightarrow \boxed{R_{F2}= 33KΩ + 3.3 KΩ}
# \end{equation}
#
# \begin{equation}
# R_G= R_{Gn}*Ω_z= 1,1219*50KΩ= 56,0950KΩ \rightarrow \boxed{R_G= 56KΩ}
# \end{equation}
#
# \begin{equation}
# R_Q= R_{Qn}*Ω_z= 0,5665*50KΩ= 28,3250KΩ\rightarrow \boxed{R_Q= 27KΩ}
# \end{equation}

# %% [markdown]
# ####
#
# ***
#
# ### <span style="text-decoration: underline;">Simulaciones</span>
#
# #### Realice una simulación numérica/simbólica en Python de la función transferencia.

# %%
#-------------------------------------------------------------------------------------------------------------------#

# Inicializamos e importamos módulos

# Módulos externos
import matplotlib as mpl
import matplotlib.pyplot as plt
import math as m
import numpy as np
import scipy.signal as sig
import csv

fig_sz_x = 10
fig_sz_y = 9
fig_dpi = 150 # dpi

fig_font_size = 12

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
#plt.rcParams.update({'font.size':fig_font_size})

#-------------------------------------------------------------------------------------------------------------------#

# Importamos las funciones de PyTC2

from pytc2.sistemas_lineales import analyze_sys
from pytc2.sistemas_lineales import pretty_print_lti

#-------------------------------------------------------------------------------------------------------------------#

# Datos de plantilla

alfa_max = 1                        # dB
alfa_min = 20                       # dB

f_s_plantilla = 1.2e3               # Hz
f_p_plantilla = 4.6e3               # Hz

omega_p_plantilla = 2*m.pi*f_p_plantilla
norm_w = omega_p_plantilla
omega_p_plantilla /= norm_w
omega_p_pb_prototipo = 1/omega_p_plantilla

omega_s_plantilla = 2*m.pi*f_s_plantilla
omega_s_plantilla /= norm_w
omega_s_pb_prototipo = 1/omega_s_plantilla

print('#---------------------------------------------------------------------------------------------#')
print(' ')
print('-- Datos de plantilla - Filtro pasa altos objetivo --')
print(' ')

print('α_min = {}'.format(alfa_min))
print('α_max = {}'.format(alfa_max))
print('fs = {}'.format(f_s_plantilla))
print('fp = {}'.format(f_p_plantilla))

print(' ')

print('ωp_n = {:3.4f}'.format(omega_p_plantilla))
print('ωs_n = {:3.4f}'.format(omega_s_plantilla))

print(' ')
print('-- Dominio transformado - Filtro pasa bajos prototipo --')
print(' ')

print('ωp = {:3.4f}'.format(omega_p_pb_prototipo))
print('ωs = {:3.4f}'.format(omega_s_pb_prototipo))

#-------------------------------------------------------------------------------------------------------------------#

# Calculamos e^2

print(' ')
print('#---------------------------------------------------------------------------------------------#')
print(' ')
print('-- ε: Grado de libertad de la funcion --')
print(' ')

print('ε = sqrt(10^(α_max/10)-1)')
eps = np.sqrt(10**(alfa_max/10)-1)

print(' ')

print('ε = {:3.4f}'.format(eps))
print('ε^2 = {:3.4f}'.format(eps**2))

print(' ')
print('#---------------------------------------------------------------------------------------------#')

#-------------------------------------------------------------------------------------------------------------------#

# Calculamos N iterando alfa_min

print(' ')
print('-- N: Orden del filtro --')
print(' ')
print('α_min = 10*log(1 + ε^2*C_n^2) con C_n^2= cosh^2(N*cosh^(-1)(ω_s))')
print(' ')

for N in range(1,10):
    C_nn = (np.cosh(N*(np.arccosh(omega_s_pb_prototipo))))**2
    att = 10*np.log10(1+(eps**2)*C_nn)    
    print('Para N= {:d}: ¿att = {:3.4f} dB >= α_min= {:d}?'.format(N, att, alfa_min))
    if att >= alfa_min:
        break

print(' ')

# Elegimos N de forma tal que α_min >= 20 dB:
print('N= {:d}'.format(N))

print(' ')
print('#---------------------------------------------------------------------------------------------#')

#-------------------------------------------------------------------------------------------------------------------#

# De la resolución analítica, obtenemos |T(jw)|^2 |w=s/j = 1 / (1 + ε^2*C_n^2) = T(s)*T(-s) 

#Cn2 = 2w^2 - 1                 # Polinomio grado 2 de Chevyshev
Cn2 = [2, 0, -1]                # Coeficientes del polinomio grado 2 de Chevyshev
Cn4 = np.polymul(Cn2, Cn2)      # Elevamos al cuadrado el denominador
Cn4 = Cn4 * eps**2              # Multiplicamos por ε^2
Cn4[4]= Cn4[4] + 1              # Sumamos 1 al término independiente
Cn4[2]= -Cn4[2]                 # Cambiamos de signo al coeficiente del término cuadrático producto del reeemplazo de w^2= s^2/j^2
Cn4 = Cn4 / (4*eps**2)          # Hacemos mónico el polinomio

p_T_lp= np.roots(Cn4)

den_T_lp= np.poly([p_T_lp for p_T_lp in p_T_lp if p_T_lp.real < 0])
num_T_lp= [m.sqrt(1/(4*eps**2))]
#print(num_T_lp)
#print(den_T_lp)

num_T_hp, den_T_hp= sig.lp2hp(num_T_lp, den_T_lp)
#print(num_T_hp)
#print(den_T_hp)

print(' ')
print('-- z_i: Ceros obtenidos con roots(p) del polinomio numerador --')
print('-- obtenido de forma analítica --')
print(' ')

print('z1,2= {}'.format(np.roots(num_T_hp)))

print(' ')
print('-- p_i: Polos en el semiplano izquierdo obtenidos con roots(p) --')
print('-- del polinomio denominador obtenido de forma analítica --')
print(' ')

print('p1,2= {}'.format(np.roots(den_T_hp)))

print(' ')
print('#---------------------------------------------------------------------------------------------#')

#-------------------------------------------------------------------------------------------------------------------#

# Obtenemos singularidades con la función de aproximación de Chevyshev del 
# filtro pasa bajos prototipo: cheb1ap(N, rp)

z, p, k = sig.cheb1ap(N, alfa_max)

#-------------------------------------------------------------------------------------------------------------------#

# Transformamos las singularidades que nos devuelve cheb1ap(N, rp) para obtener 
# el numerador y el denominador de la T_LP(s) del filtro pasa bajos prototipo 
# con zpk2tf(z,p,k):

num_lp, den_lp = sig.zpk2tf(z,p,k)

#-------------------------------------------------------------------------------------------------------------------#

# Transformamos la T_LP(s) del filtro pasa bajos prototipo para obtener 
# el numerador y el denominador de la T_HP(s) con lp2hp(num, den):

num_hp, den_hp = sig.lp2hp(num_lp, den_lp)

print(' ')
print('-- z_i: Ceros obtenidos con cheb1ap(N, rp) coincidentes --')
print('con los obtenidos con roots(p) de forma analítica --')
print(' ')

print('z1,2= {}'.format(np.roots(num_hp)))

print(' ')
print('-- p_i: Polos en el semiplano izquierdo obtenidos con cheb1ap(N, rp) --')
print('-- coincidentes con los obtenidos con roots(p) de forma analítica --')
print(' ')

print('p1,2= {}'.format(np.roots(den_hp)))

print(' ')
print('#---------------------------------------------------------------------------------------------#')

#-------------------------------------------------------------------------------------------------------------------#

# Transformamos (factorizamos) la T(s) en secciones de segundo orden (SOS) con la función tf2sos_analog()
#this_sos = tf2sos_analog(num_hp, den_hp)

t_T_hp= sig.TransferFunction(num_T_hp, den_T_hp)             # numerador y denominador resolución analítica

t_hp= sig.TransferFunction(num_hp, den_hp)                   # numerador y denominador con cheb1ap()

#-------------------------------------------------------------------------------------------------------------------#

# Imprimimos la T(s) en formato T(s)= num/den con la funcion pretty_print_lti(num, den):

print(' ')
print('-- Función transferencia T(s) analítica normalizada: --')
print(' ')

pretty_print_lti(num_T_hp, den_T_hp)

print(' ')
print('-- Función transferencia T(s) normalizada con cheb1ap(N, rp): --')
print(' ')

pretty_print_lti(num_hp, den_hp)

print(' ')
print('#---------------------------------------------------------------------------------------------#')
print(' ')

#-------------------------------------------------------------------------------------------------------------------#

# Representamos módulo, fase, diagrama de polos y ceros y retardo de fase con la analyze_sys() que tiene, entre
# otras cosas, indicadores (w0 y Q) de las singularidades en el diagrama de polos y ceros

print('-- Módulo, fase, diagrama de polos y ceros y retardo de fase --')
print(' ')

analyze_sys(t_hp, sys_name='Filtro pasa alto Chebyshev 2do orden normalizado')

#-------------------------------------------------------------------------------------------------------------------#
# Out:
# #---------------------------------------------------------------------------------------------#
#
# -- Datos de plantilla - Filtro pasa altos objetivo --
#
# α_min = 20
# α_max = 1
# fs = 1200.0
# fp = 4600.0
#
# ωp_n = 1.0000
# ωs_n = 0.2609
#
# -- Dominio transformado - Filtro pasa bajos prototipo --
#
# ωp = 1.0000
# ωs = 3.8333
#
# #---------------------------------------------------------------------------------------------#
#
# -- ε: Grado de libertad de la funcion --
#
# ε = sqrt(10^(α_max/10)-1)
#
# ε = 0.5088
# ε^2 = 0.2589
#
# #---------------------------------------------------------------------------------------------#
#
# -- N: Orden del filtro --
#
# α_min = 10*log(1 + ε^2*C_n^2) con C_n^2= cosh^2(N*cosh^(-1)(ω_s))
#
# Para N= 1: ¿att = 6.8167 dB >= α_min= 20?
# Para N= 2: ¿att = 23.2155 dB >= α_min= 20?
#
# N= 2
#
# #---------------------------------------------------------------------------------------------#
#
# ...

# %%
#-------------------------------------------------------------------------------------------------------------------#

# Calculamos transferencia desnormalizada:

num_hp_desn = num_hp
den_hp_desn = den_hp * [1,norm_w,norm_w*norm_w]

t_hp_desn = sig.TransferFunction(num_hp_desn, den_hp_desn)

#-------------------------------------------------------------------------------------------------------------------#

# Imprimimos la T(s) desnormalizada en formato T(s)= num/den con la funcion pretty_print_lti(num, den):

print(' ')
print('-- Función transferencia T(s) analítica desnormalizada: --')
print(' ')

pretty_print_lti(num_hp_desn, den_hp_desn)

print(' ')
print('#---------------------------------------------------------------------------------------------#')
print(' ')

#-------------------------------------------------------------------------------------------------------------------#

# Representamos módulo, fase, diagrama de polos y ceros y retardo de fase con la analyze_sys() que tiene, entre
# otras cosas, indicadores (w0 y Q) de las singularidades en el diagrama de polos y ceros

#print('-- Módulo, fase, diagrama de polos y ceros y retardo de fase --')
#print(' ')

#analyze_sys(t_hp_desn, sys_name='Filtro pasa alto Chebyshev 2do orden desnormalizado')

#-------------------------------------------------------------------------------------------------------------------#
# Out:
#
# -- Función transferencia T(s) analítica desnormalizada: --
# $\displaystyle \frac{s^2 \,\, 0.8913 }{s^2 + s \,\, 2.878e+04 + 7.577e+08 }$
#
# #---------------------------------------------------------------------------------------------#

# %% [markdown]
# <br>
#
# #### Simulación circuital en Spice usando modelo discreto para el UAF42.

# %% [markdown]
# La primer simulación se hizo con valores de $R_f= 39KΩ$ por estar mas cercanos a los $36K$ calculados. Sin embargo para el diseño final se adoptara lo indicado en la síntesis y el calculo anterior.

# %% [markdown]
# <img src="CIR_SIM_UAF.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# <img src="SIM_VAR_EST.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# #### Otra simulación con respuesta y fase separadas.

# %% [markdown]
# <img src="img/TPL1_Circuito_Esquematico.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# <img src="img/TPL1_Respuesta_modulo_HP.png" style="margin-left:auto; margin-right:auto"/>
#
# <img src="img/TPL1_Respuesta_fase_HP.png" style="margin-left:auto; margin-right:auto"/>
#
# <img src="img/TPL1_Respuesta_retardo_grupo_HP.png" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# ***
# ### Conclusiones de la síntesis ###
# Como se pudo observar, se consiguio una muy buena respuesta ajustada a la plantilla pedida mediante el calculo de la función transferencia y la posterior simulación empleando el filtro variable de estados que se ajusta al UAF42. Para el diseño final se debió considerar los valores comerciales de resistencias para el armado y se ajustaron estos valores a los posibles. Por otro lado las resistencias $R_f$ del diseño se implementan mediante dos resistores serie de $33 K\Omega$ y $ 3.3K\Omega$ para conseguir los valores buscados. En el caso de $R_q$ y $R_g$ se implementaran en serie con presets ajustables para poder observar en la práctica los efectos del ajuste sobre los parametros de Ganancia y Q.

# %% [markdown]
# ***
# ### Armado del circuito y Ensayo del circuito
# ***

# %% [markdown]
# #### Setup de medición

# %% [markdown]
# A continuación mostramos como se dispusieron los intrumentos y el filtro a medir:

# %% [markdown]
# <img src="Setup.jpg" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# #### Procedimiento para la medición

# %% [markdown]
# 1- Se Verifico visualmente y con el multímetro que el circuito no tenía cortocircuitos y que los componentes estaban correctamente soldados.
#
# 2- Se utilizo la limitación de corriente de la fuente en algunas decenas de mA.
#
# 3- Se calibro la tensión de la fuente.
#
# 4- Se verificaron las puntas del osciloscopio mediantela señal de prueba tanto en el canal 1 como 2.
#
# 5- Se calibro una señal senoidal en el generador a un nivel que optimiza la medición en la banda de paso de   valor medio nulo con el generador.
#
# 6- Se elijio una frecuencia en la mitad de la banda de paso del diseño asignado (en esete caso $4.5 KHz$).
#
# 7- Se desenergizo el circuito se y conecto el integrado. Se conecto la alimentación nuevamente y el generador de entrada.
#
# 8- Verificamos con el osciloscopio que tenía señal a la salida.
#
# 9- Se realiza el barrido en frecuencia sobre el filtro rápido y cualitativo. Al mismo tiempo se mide el desfasaje entre señal de entrada y salida, de tal manera de calcular luego el desfasaje en función del $ \Delta t $

# %% [markdown]
# Siguiendo el circuito obtenido en la síntesis, se monto el circuito sobre una placa universal

# %% [markdown]
# A continuación se muestra el procesamiento de los datos obtenidos a partir del procedimiento de medición, de tal manera de obtener las respuestas de módulo y fase:

# %%
#-----------------------------------------------------------------------------------------------------------------------#

ruta_archivo = 'Sweep_Data_0.csv'

freq_mod= []
resp_mod = []

with open(ruta_archivo, 'r') as archivo_csv:
    lector_csv = csv.reader(archivo_csv)
    
    qty_rows_values = 100
    qty_rows_titles = 3
    qty_rows_blanks = 1
    qty_rows_freq_vs_freq = qty_rows_titles + qty_rows_values
    qty_rows_total = qty_rows_values + qty_rows_blanks + qty_rows_titles + qty_rows_values
    row_index = 0
    
    for row_freq_resp in lector_csv:
        #print('{}'.format(row_index))
        row_index += 1
        if ( row_index > ( qty_rows_freq_vs_freq + qty_rows_blanks + qty_rows_titles ) and row_index < qty_rows_total ):
            freq_mod_data, resp_mod_data = row_freq_resp
            freq_mod.append(float(freq_mod_data))
            resp_mod.append(float(resp_mod_data))

figura_1= plt.figure()
plt.plot(freq_mod, resp_mod)

plt.xscale('log')

plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Ganancia [dB]')

dresp= 10
plt.xlim(min(freq_mod), max(freq_mod))
plt.ylim(min(resp_mod), max(resp_mod)+dresp)

plt.grid(True, which= 'both')

plt.title('Respuesta en Frecuencia - Filtro Pasabajos')

plt.show()


#-----------------------------------------------------------------------------------------------------------------------#

ruta_archivo = 'Sweep_Data_1.csv'

freq_fase = []
resp_fase_ch1 = []
resp_fase_ch2 = []

with open(ruta_archivo, 'r') as archivo_csv:
    lector_csv = csv.reader(archivo_csv)
    
    qty_rows_values = 100
    qty_rows_titles = 3
    qty_rows_blanks = 1
    qty_rows_freq_vs_freq = qty_rows_titles + qty_rows_values
    qty_rows_total = qty_rows_values + qty_rows_blanks + qty_rows_titles + qty_rows_values
    row_index = 0
    
    for row_freq_resp_fase in lector_csv:
        #print('{}'.format(row_index))
        row_index += 1
        if ( row_index > ( qty_rows_freq_vs_freq + qty_rows_blanks + qty_rows_titles ) and row_index < qty_rows_total ):
            freq_fase_data, resp_fase_ch1_data = row_freq_resp_fase
            freq_fase.append(float(freq_fase_data))
            resp_fase_ch1.append(float(resp_fase_ch1_data))
            #resp_fase_ch2.append(float(resp_fase_ch2_data))

figura_1= plt.figure()
plt.plot(freq_fase, resp_fase_ch1)
#plt.plot(freq_fase, resp_fase_ch2)

plt.xscale('log')

plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Fase [º]')

dresp= 10
plt.xlim(min(freq_fase), max(freq_fase))
plt.ylim(min(resp_fase_ch1), max(resp_fase_ch1)+dresp)

plt.grid(True, which= 'both')

plt.title('Respuesta de Fase - Filtro Pasabajos')

plt.show()


#-----------------------------------------------------------------------------------------------------------------------#

# %% [markdown]
# Como podemos observar cumplimos con la plantilla de módulo, y en cuanto a la fase se muestra cierta dispersión respecto de la forma esperada. A continuación observamos la respuesta obtenida mediante el analizador de frecuencia:

# %% [markdown]
# <img src="Modulo_frec.jpeg" style="margin-left:auto; margin-right:auto"/>
# <img src="Fase_frec.jpeg" style="margin-left:auto; margin-right:auto"/>

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# * Mediante
